# %% [markdown]
# ## Import Package

# %%
import pandas as pd
from AutoLookalike.auto_predictor import AutoPredictor

# %% [markdown]
# ## Load Data

# %%
data = pd.read_csv('data/new_model_test_data.csv', index_col=0)
target = 'GB_IND'

# %% [markdown]
# ## Init AutoPredictor

# %%
auto_predictor = AutoPredictor(data, target)
# Out:
# ProcessFlow init finish
# Core Model Initialized:
# XGBClassifier(base_score=None, booster='gbtree', colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=None, gamma=None, gpu_id=None,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=None,
#               tree_method=None, use_label_encoder=False,
#               validate_parameters=None, verbosity=0)
# ModelFlow init finish

# %% [markdown]
# ## Processing

# %%
auto_predictor.process()
# Out:
# Data Spliting: Train data size ((160000, 52))  Test data size ((40000, 52))
# Doing Train Data Processing...
# Processing stage: fillna
# Processing stage: fillna
# Processing categorical features...
# /Users/patrickleung/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:4439: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
# Processing categorical features...
# Data Process Finish, Time consume: 14.710519075393677
# Model Fitting ...
# execute:[fit] consume:[38.71213388442993]
# Evaluating Model Performance
# Doing Test Data Processing...
# Processing stage: fillna
# Processing stage: fillna
# Processing categorical features...
# Processing categorical features...
# Data Process Finish, Time consume: 0.1781299114227295
# ...

# %% [markdown]
# ## Feature Analysis

# %%
auto_predictor.summary()
